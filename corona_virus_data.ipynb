# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Data Overview

# %% [markdown]
# - A new coronavirus designated 2019-nCoV was first identified in Wuhan, the capital of China's Hubei province
# - People developed pneumonia without a clear cause and for which existing vaccines or treatments were not effective.
# - The virus has shown evidence of human-to-human transmission
# - Transmission rate (rate of infection) appeared to escalate in mid-January 2020
# - As of 30 January 2020, approximately 8,243 cases have been confirmed

# %% [markdown]
# # CONTENT

# %% [markdown]
# - 1)Introduction to Dataset.
# - 2)Null Value and Reduction.
# - 3)Rename Features
# - 4)Statistical Information
# - 5)Statistical Figures
# - 6)Pivot Tables
# - 7)Cross Tabs
# - 8)Total Counting by Country

# %% [markdown]
# # Visualizations

# %% [markdown]
# - 9)Bar Plot
# - 10)Count Plot
# - 11)Heat Map
# - 12)Pie Plot
# - 13)Conclusions

# %%
cd=pd.read_csv('country_wise_latest.csv')
cd
# Out:
#          Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 0           Afghanistan      36263    1269      25198    9796        106
# 1               Albania       4880     144       2745    1991        117
# 2               Algeria      27973    1163      18837    7973        616
# 3               Andorra        907      52        803      52         10
# 4                Angola        950      41        242     667         18
# ..                  ...        ...     ...        ...     ...        ...
# 182  West Bank and Gaza      10621      78       3752    6791        152
# 183      Western Sahara         10       1          8       1          0
# 184               Yemen       1691     483        833     375         10
# 185              Zambia       4552     140       2815    1597         71
# 186            Zimbabwe       2704      36        542    2126        192
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# ...

# %% [markdown]
# # Introduction to  dataset

# %%
cd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 187 entries, 0 to 186
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Country/Region          187 non-null    object
#  1   Confirmed               187 non-null    int64
#  2   Deaths                  187 non-null    int64
#  3   Recovered               187 non-null    int64
#  4   Active                  187 non-null    int64
#  5   New cases               187 non-null    int64
#  6   New deaths              187 non-null    int64
#  7   New recovered           187 non-null    int64
#  8   Deaths / 100 Cases      187 non-null    float64
#  9   Recovered / 100 Cases   187 non-null    float64
#  10  Deaths / 100 Recovered  187 non-null    float64
#  11  Confirmed last week     187 non-null    int64
#  12  1 week change           187 non-null    int64
#  13  1 week % increase       187 non-null    float64
# ...

# %%
cd.columns
# Out:
# Index(['Country/Region', 'Confirmed', 'Deaths', 'Recovered', 'Active',
#        'New cases', 'New deaths', 'New recovered', 'Deaths / 100 Cases',
#        'Recovered / 100 Cases', 'Deaths / 100 Recovered',
#        'Confirmed last week', '1 week change', '1 week % increase',
#        'WHO Region'],
#       dtype='object')

# %%
cd.describe()
# Out:
#           Confirmed         Deaths     Recovered        Active     New cases  \
# count  1.870000e+02     187.000000  1.870000e+02  1.870000e+02    187.000000
# mean   8.813094e+04    3497.518717  5.063148e+04  3.400194e+04   1222.957219
# std    3.833187e+05   14100.002482  1.901882e+05  2.133262e+05   5710.374790
# min    1.000000e+01       0.000000  0.000000e+00  0.000000e+00      0.000000
# 25%    1.114000e+03      18.500000  6.265000e+02  1.415000e+02      4.000000
# 50%    5.059000e+03     108.000000  2.815000e+03  1.600000e+03     49.000000
# 75%    4.046050e+04     734.000000  2.260600e+04  9.149000e+03    419.500000
# max    4.290259e+06  148011.000000  1.846641e+06  2.816444e+06  56336.000000
#
#         New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# count   187.000000     187.000000          187.000000             187.000000
# mean     28.957219     933.812834            3.019519              64.820535
# ...

# %%
cd.shape
# Out:
# (187, 15)

# %%
cd.nunique()
# Out:
# Country/Region            187
# Confirmed                 184
# Deaths                    150
# Recovered                 178
# Active                    173
# New cases                 122
# New deaths                 38
# New recovered             103
# Deaths / 100 Cases        145
# Recovered / 100 Cases     177
# Deaths / 100 Recovered    155
# Confirmed last week       183
# 1 week change             162
# 1 week % increase         169
# WHO Region                  6
# dtype: int64

# %%
cd.head()
# Out:
#   Country/Region  Confirmed  Deaths  Recovered  Active  New cases  New deaths  \
# 0    Afghanistan      36263    1269      25198    9796        106          10
# 1        Albania       4880     144       2745    1991        117           6
# 2        Algeria      27973    1163      18837    7973        616           8
# 3        Andorra        907      52        803      52         10           0
# 4         Angola        950      41        242     667         18           1
#
#    New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0             18                3.50                  69.49
# 1             63                2.95                  56.25
# 2            749                4.16                  67.34
# 3              0                5.73                  88.53
# 4              0                4.32                  25.47
#
#    Deaths / 100 Recovered  Confirmed last week  1 week change  \
# 0                    5.04                35526            737
# ...

# %% [markdown]
# - Top 5 country for the Covid cases.

# %%
cd.tail()
# Out:
#          Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 182  West Bank and Gaza      10621      78       3752    6791        152
# 183      Western Sahara         10       1          8       1          0
# 184               Yemen       1691     483        833     375         10
# 185              Zambia       4552     140       2815    1597         71
# 186            Zimbabwe       2704      36        542    2126        192
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 182           2              0                0.73                  35.33
# 183           0              0               10.00                  80.00
# 184           4             36               28.56                  49.26
# 185           1            465                3.08                  61.84
# 186           2             24                1.33                  20.04
#
#      Deaths / 100 Recovered  Confirmed last week  1 week change  \
# ...

# %% [markdown]
# - Bottom 5 country for the Covid cases.

# %%
cd.isnull().sum()
# Out:
# Country/Region            0
# Confirmed                 0
# Deaths                    0
# Recovered                 0
# Active                    0
# New cases                 0
# New deaths                0
# New recovered             0
# Deaths / 100 Cases        0
# Recovered / 100 Cases     0
# Deaths / 100 Recovered    0
# Confirmed last week       0
# 1 week change             0
# 1 week % increase         0
# WHO Region                0
# dtype: int64

# %% [markdown]
# - There is no null values in the dataset, so our dataset is clean.

# %% [markdown]
# # 2) Null Values & Reduction of Feature

# %%
cd.drop(['New recovered','Confirmed last week','New deaths'], axis =1, inplace= True)

# %%
cd
# Out:
#          Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 0           Afghanistan      36263    1269      25198    9796        106
# 1               Albania       4880     144       2745    1991        117
# 2               Algeria      27973    1163      18837    7973        616
# 3               Andorra        907      52        803      52         10
# 4                Angola        950      41        242     667         18
# ..                  ...        ...     ...        ...     ...        ...
# 182  West Bank and Gaza      10621      78       3752    6791        152
# 183      Western Sahara         10       1          8       1          0
# 184               Yemen       1691     483        833     375         10
# 185              Zambia       4552     140       2815    1597         71
# 186            Zimbabwe       2704      36        542    2126        192
#
#      Deaths / 100 Cases  Recovered / 100 Cases  Deaths / 100 Recovered  \
# ...

# %% [markdown]
# # 3) Rename Column Name

# %%
cd.rename(columns = {'1 week change':'changes','1 week % increase':'increase','Country/Region':'Country','Deaths / 100 Cases':'Avg Deaths Recovered',
                    'Recovered / 100 Cases':'Avg Recovered','Deaths / 100 Recovered':'Deaths Avg Recovered'}, inplace = True)

# %%
cd.columns
# Out:
# Index(['Country', 'Confirmed', 'Deaths', 'Recovered', 'Active', 'New cases',
#        'Avg Deaths Recovered', 'Avg Recovered', 'Deaths Avg Recovered',
#        'changes', 'increase', 'WHO Region'],
#       dtype='object')

# %% [markdown]
# - We Rename our Feature name for better readability of the data.

# %% [markdown]
# # 4) Statistical Information

# %% [markdown]
# Correlation

# %% [markdown]
# - it is relation between Two group or Two column or Feature.
# - Relation Between +1 to -1.

# %%
cd.corr()
# Out:
#                       Confirmed    Deaths  Recovered    Active  New cases  \
# Confirmed              1.000000  0.934698   0.906377  0.927018   0.909720
# Deaths                 0.934698  1.000000   0.832098  0.871586   0.806975
# Recovered              0.906377  0.832098   1.000000  0.682103   0.818942
# Active                 0.927018  0.871586   0.682103  1.000000   0.851190
# New cases              0.909720  0.806975   0.818942  0.851190   1.000000
# Avg Deaths Recovered   0.063550  0.251565   0.048438  0.054380   0.020104
# Avg Recovered         -0.064815 -0.114529   0.026610 -0.132618  -0.078666
# Deaths Avg Recovered   0.025175  0.169006  -0.027277  0.058386  -0.011637
# changes                0.954710  0.855330   0.910013  0.847642   0.959993
# increase              -0.010161 -0.034708  -0.013697 -0.003752   0.030791
#
#                       Avg Deaths Recovered  Avg Recovered  \
# Confirmed                         0.063550      -0.064815
# ...

# %% [markdown]
# # Covariance

# %% [markdown]
# - Covariance provides the a measure of strength of correlation between two variable or more set of variables.
# - The mean of each variable is used as reference and relative positions of observations compared to mean is important.

# %%
cd.cov()
# Out:
#                          Confirmed        Deaths     Recovered        Active  \
# Confirmed             1.469332e+11  5.051853e+09  6.607730e+10  7.580405e+10
# Deaths                5.051853e+09  1.988101e+08  2.231400e+09  2.621643e+09
# Recovered             6.607730e+10  2.231400e+09  3.617155e+10  2.767435e+10
# Active                7.580405e+10  2.621643e+09  2.767435e+10  4.550806e+10
# New cases             1.991280e+09  6.497460e+07  8.894084e+08  1.036897e+09
# Avg Deaths Recovered  8.414702e+04  1.225266e+04  3.182232e+04  4.007204e+04
# Avg Recovered        -6.531143e+05 -4.245097e+04  1.330389e+05 -7.437022e+05
# Deaths Avg Recovered           NaN           NaN           NaN           NaN
# changes               1.737976e+10  5.727502e+08  8.219465e+09  8.587547e+09
# increase             -9.546070e+04 -1.199456e+04 -6.384851e+04 -1.961763e+04
#
#                          New cases  Avg Deaths Recovered  Avg Recovered  \
# ...

# %% [markdown]
# # Standard Deviation

# %% [markdown]
# - A quantity expressing by how much the members of a group differ from the mean value for the group.
# - The standard deviation is used in conjunction with the mean to summarise continuous data, not categorical data.

# %%
cd.std()
# Out:
# Confirmed               383318.663831
# Deaths                   14100.002482
# Recovered               190188.189643
# Active                  213326.173371
# New cases                 5710.374790
# Avg Deaths Recovered         3.454302
# Avg Recovered               26.287694
# Deaths Avg Recovered              NaN
# changes                  47491.127684
# increase                    24.509838
# dtype: float64

# %% [markdown]
# # 5) Statistical Figures

# %% [markdown]
# - A statistic or sample statistic is any quantity computed from values in a sample which is considered for a statistical purpose.
# - Statistical purposes include estimating a population parameter

# %%
cd.columns
# Out:
# Index(['Country', 'Confirmed', 'Deaths', 'Recovered', 'Active', 'New cases',
#        'Avg Deaths Recovered', 'Avg Recovered', 'Deaths Avg Recovered',
#        'changes', 'increase', 'WHO Region'],
#       dtype='object')

# %%
cd['Country'].count()
# Out:
# 187

# %%
cd['WHO Region'].value_counts()
# Out:
# Europe                   56
# Africa                   48
# Americas                 35
# Eastern Mediterranean    22
# Western Pacific          16
# South-East Asia          10
# Name: WHO Region, dtype: int64

# %%
cd[cd['increase'] >= 50.00]
# Out:
#               Country  Confirmed  Deaths  Recovered  Active  New cases  \
# 11            Bahamas        382      11         91     280         40
# 63             Gambia        326       8         66     252         49
# 130  Papua New Guinea         62       0         11      51          0
# 186          Zimbabwe       2704      36        542    2126        192
#
#      Avg Deaths Recovered  Avg Recovered  Deaths Avg Recovered  changes  \
# 11                   2.88          23.82                 12.09      208
# 63                   2.45          20.25                 12.12      214
# 130                  0.00          17.74                  0.00       43
# 186                  1.33          20.04                  6.64      991
#
#      increase       WHO Region
# 11     119.54         Americas
# 63     191.07           Africa
# 130    226.32  Western Pacific
# 186     57.85           Africa

# %% [markdown]
# - Cases Increase More than 50% in all the country

# %% [markdown]
# # 6) Pivot Tables

# %%
PV1=pd.pivot_table(cd,values='Confirmed', index=['Country'],
                  columns=['WHO Region'], aggfunc=np.sum)
PV1
# Out:
# WHO Region           Africa  Americas  Eastern Mediterranean  Europe  \
# Country
# Afghanistan             NaN       NaN                36263.0     NaN
# Albania                 NaN       NaN                    NaN  4880.0
# Algeria             27973.0       NaN                    NaN     NaN
# Andorra                 NaN       NaN                    NaN   907.0
# Angola                950.0       NaN                    NaN     NaN
# ...                     ...       ...                    ...     ...
# West Bank and Gaza      NaN       NaN                10621.0     NaN
# Western Sahara         10.0       NaN                    NaN     NaN
# Yemen                   NaN       NaN                 1691.0     NaN
# Zambia               4552.0       NaN                    NaN     NaN
# Zimbabwe             2704.0       NaN                    NaN     NaN
#
# WHO Region          South-East Asia  Western Pacific
# Country
# Afghanistan                     NaN              NaN
# ...

# %% [markdown]
# - Pivot Table show the WHO Region wise confirmed covid cases in all over the countries.

# %% [markdown]
# # 7) Crosstab

# %% [markdown]
# - Table showing the relationship between two or more variables. Where the table only shows the relationship between two categorical variables, a crosstab
# is also known as a contingency table.
# - It helps us to make informed decisions regarding your research by identifying patterns, trends, and the correlation between your study parameters.

# %%
pd.crosstab(cd["WHO Region"],cd["Country"])
# Out:
# Country                Afghanistan  Albania  Algeria  Andorra  Angola  \
# WHO Region
# Africa                           0        0        1        0       1
# Americas                         0        0        0        0       0
# Eastern Mediterranean            1        0        0        0       0
# Europe                           0        1        0        1       0
# South-East Asia                  0        0        0        0       0
# Western Pacific                  0        0        0        0       0
#
# Country                Antigua and Barbuda  Argentina  Armenia  Australia  \
# WHO Region
# Africa                                   0          0        0          0
# Americas                                 1          1        0          0
# Eastern Mediterranean                    0          0        0          0
# Europe                                   0          0        1          0
# South-East Asia                          0          0        0          0
# ...

# %% [markdown]
# Cross Tab is show the observation country by WHO Region.

# %% [markdown]
# # 8) Total Counting by Country

# %%
Total = cd.groupby("WHO Region")["Deaths"].sum()
Total
# Out:
# WHO Region
# Africa                    12223
# Americas                 342732
# Eastern Mediterranean     38339
# Europe                   211144
# South-East Asia           41349
# Western Pacific            8249
# Name: Deaths, dtype: int64

# %%
Death_Case = cd[['Country','Deaths']].sort_values(by=['Deaths'],ascending=False).head(10)
Death_Case
# Out:
#             Country  Deaths
# 173              US  148011
# 23           Brazil   87618
# 177  United Kingdom   45844
# 111          Mexico   44022
# 85            Italy   35112
# 79            India   33408
# 61           France   30212
# 157           Spain   28432
# 132            Peru   18418
# 81             Iran   15912

# %%
Recovery_Case = cd[['Country','Recovered']].sort_values(by=['Recovered'],ascending=False).head(10)
Recovery_Case
# Out:
#           Country  Recovered
# 23         Brazil    1846641
# 173            US    1325804
# 79          India     951166
# 138        Russia     602249
# 35          Chile     319954
# 111        Mexico     303810
# 154  South Africa     274925
# 132          Peru     272547
# 81           Iran     255144
# 128      Pakistan     241026

# %%
Active_Case = cd[['Country','Active']].sort_values(by=['Active'],ascending=False).head(10)
Active_Case
# Out:
#             Country   Active
# 173              US  2816444
# 23           Brazil   508116
# 79            India   495499
# 177  United Kingdom   254427
# 138          Russia   201097
# 154    South Africa   170537
# 37         Colombia   117163
# 61           France   108928
# 32           Canada   107514
# 132            Peru    98752

# %%
cd.groupby(['WHO Region'])[['Country']].count()
# Out:
#                        Country
# WHO Region
# Africa                      48
# Americas                    35
# Eastern Mediterranean       22
# Europe                      56
# South-East Asia             10
# Western Pacific             16

# %% [markdown]
# - The count of Country Group according to WHO Region.

# %% [markdown]
# # Visualisation

# %% [markdown]
# 1) Bar Plot

# %%
plt.figure(figsize=(18,5))
plt.bar('WHO Region','Deaths',data=cd,color='g')
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# 2) Recovery Rate Plot

# %%
plt.figure(figsize=(18,5))
plt.bar('WHO Region','Recovered',data=cd,color='r')
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# 3) Active Case Plot

# %%
plt.figure(figsize=(18,5))
plt.bar('WHO Region','Active',data=cd,color='cyan')
plt.xticks(rotation=0)
plt.show()

# %%
plt.figure(figsize=(20,6))
sns.countplot(x=cd['WHO Region'],palette='coolwarm_r')
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# # 11) Heat Map

# %%
sns.heatmap(cd.corr())
plt.show()

# %% [markdown]
# # 12) PIE Plot

# %%
plt.title('WHO Region',fontsize=20)
cd['WHO Region'].value_counts().plot.pie(autopct='%1.1f%%',shadow=True)
plt.show()

# %% [markdown]
# # 13) Conclusions

# %% [markdown]
# - By the Observation of Count Plot and Pie Plot we observe the Europe Region has the Highest Cases in the World with the 29.69% of weightage.
# - By the Observation of Count Plot and Pie Plot we observe the South-East Asia Region has the Lowest Cases in the World with the 5.3% of weightage.
# - From the Group By Table we observe that Europe Region Contain 56 countries which has the highest count cases of Covid-19.
# - From the Group By Table we observe that South-East Asia Region Contain 10 countries which has the LOwets count cases of Covid-19
